# %% [markdown]
# # 读取数据，查看数据，处理数据

# %%
import pandas as pd 
df = pd.read_csv('../data/menu.csv',encoding='utf8')
df.head()
# Out:
#                     name                                              foods  score kind
# 0               超级下饭的地三鲜                      长茄子、青椒、土豆、蚝油、生抽、盐、糖、老抽、淀粉、葱、蒜    8.0  家常菜
# 1             农家一碗香（下饭菜）                         青红椒、鸡蛋、五花肉、生抽、老抽、蚝油、葱姜蒜、料酒    8.1  家常菜
# 2                  土豆焖牛腩  牛腩、土豆、胡萝卜、葱、姜、蒜、八角、香叶、桂皮、陈皮、花椒、水、腐乳（王致和大块腐乳）、腐...    9.3  家常菜
# 3  蚂蚁上树(肉末炒粉丝)超下饭‼️十分钟搞定                 红薯粉丝、肉末(猪肉糜)、葱花、姜片、盐、料酒、酱油、豆瓣酱、糖、油    8.3  家常菜
# 4           和饭店一个味道的干锅花菜                     花菜、肥五花、青红线椒、姜，大蒜、芹菜、料酒、盐、耗油、生抽    7.8  家常菜

# %%
# 查看缺失值
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5191 entries, 0 to 5190
# Data columns (total 4 columns):
# name     5191 non-null object
# foods    5190 non-null object
# score    5191 non-null float64
# kind     5191 non-null object
# dtypes: float64(1), object(3)
# memory usage: 162.3+ KB

# %%
# 删除缺失值
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5190 entries, 0 to 5190
# Data columns (total 4 columns):
# name     5190 non-null object
# foods    5190 non-null object
# score    5190 non-null float64
# kind     5190 non-null object
# dtypes: float64(1), object(3)
# memory usage: 202.7+ KB

# %% [markdown]
# # Apriori 算法

# %%
# -*- coding: utf-8 -*-

# 代码8-6 构建关联规则模型

from numpy import *


def loadDataSet():
    return [['a', 'c', 'e'], ['b', 'd'], ['b', 'c'], ['a', 'b', 'c', 'd'], ['a', 'b'], ['b', 'c'], ['a', 'b'],
            ['a', 'b', 'c', 'e'], ['a', 'b', 'c'], ['a', 'c', 'e']]


def createC1(dataSet):
    C1 = []
    for transaction in dataSet:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
    C1.sort()
    # 映射为frozenset唯一性的，可使用其构造字典
    return list(map(frozenset, C1))


# 从候选K项集到频繁K项集（支持度计算）
def scanD(D, Ck, minSupport):
    ssCnt = {}
    for tid in D:  # 遍历数据集
        for can in Ck:  # 遍历候选项
            if can.issubset(tid):  # 判断候选项中是否含数据集的各项
                if not can in ssCnt:
                    ssCnt[can] = 1  # 不含设为1
                else:
                    ssCnt[can] += 1  # 有则计数加1
    numItems = float(len(D))  # 数据集大小
    retList = []  # L1初始化
    supportData = {}  # 记录候选项中各个数据的支持度
    for key in ssCnt:
        support = ssCnt[key] / numItems  # 计算支持度
        if support >= minSupport:
            retList.insert(0, key)  # 满足条件加入L1中
            supportData[key] = support
    return retList, supportData


def calSupport(D, Ck, min_support):
    dict_sup = {}
    for i in D:
        for j in Ck:
            if j.issubset(i):
                if not j in dict_sup:
                    dict_sup[j] = 1
                else:
                    dict_sup[j] += 1
    sumCount = float(len(D))
    supportData = {}
    relist = []
    for i in dict_sup:
        temp_sup = dict_sup[i] / sumCount
        if temp_sup >= min_support:
            relist.append(i)
            # 此处可设置返回全部的支持度数据（或者频繁项集的支持度数据）
            supportData[i] = temp_sup
    return relist, supportData


# 改进剪枝算法
def aprioriGen(Lk, k):
    retList = []
    lenLk = len(Lk)
    for i in range(lenLk):
        for j in range(i + 1, lenLk):  # 两两组合遍历
            L1 = list(Lk[i])[:k - 2]
            L2 = list(Lk[j])[:k - 2]
            L1.sort()
            L2.sort()
            if L1 == L2:  # 前k-1项相等，则可相乘，这样可防止重复项出现
                # 进行剪枝（a1为k项集中的一个元素，b为它的所有k-1项子集）
                a = Lk[i] | Lk[j]  # a为frozenset()集合
                a1 = list(a)
                b = []
                # 遍历取出每一个元素，转换为set，依次从a1中剔除该元素，并加入到b中
                for q in range(len(a1)):
                    t = [a1[q]]
                    tt = frozenset(set(a1) - set(t))
                    b.append(tt)
                t = 0
                for w in b:
                    # 当b（即所有k-1项子集）都是Lk（频繁的）的子集，则保留，否则删除。
                    if w in Lk:
                        t += 1
                if t == len(b):
                    retList.append(b[0] | b[1])
    return retList


def apriori(dataSet, minSupport=0.2):
    # 前3条语句是对计算查找单个元素中的频繁项集
    C1 = createC1(dataSet)
    D = list(map(set, dataSet))  # 使用list()转换为列表
    L1, supportData = calSupport(D, C1, minSupport)
    L = [L1]  # 加列表框，使得1项集为一个单独元素
    k = 2
    while (len(L[k - 2]) > 0):  # 是否还有候选集
        Ck = aprioriGen(L[k - 2], k)
        Lk, supK = scanD(D, Ck, minSupport)  # scan DB to get Lk
        supportData.update(supK)  # 把supk的键值对添加到supportData里
        L.append(Lk)  # L最后一个值为空集
        k += 1
    del L[-1]  # 删除最后一个空集
    return L, supportData  # L为频繁项集，为一个列表，1，2，3项集分别为一个元素


# 生成集合的所有子集
def getSubset(fromList, toList):
    for i in range(len(fromList)):
        t = [fromList[i]]
        tt = frozenset(set(fromList) - set(t))
        if not tt in toList:
            toList.append(tt)
            tt = list(tt)
            if len(tt) > 1:
                getSubset(tt, toList)


def calcConf(freqSet, H, supportData, ruleList, minConf=0.7):
    for conseq in H:  # 遍历H中的所有项集并计算它们的可信度值
        conf = supportData[freqSet] / supportData[freqSet - conseq]  # 可信度计算，结合支持度数据
        # 提升度lift计算lift = p(a & b) / p(a)*p(b)
        lift = supportData[freqSet] / (supportData[conseq] * supportData[freqSet - conseq])

        if conf >= minConf and lift > 1:
            print(freqSet - conseq, '-->', conseq, '支持度', round(supportData[freqSet], 6), '置信度：', round(conf, 6),
                  'lift值为：', round(lift, 6))
            ruleList.append((freqSet - conseq, conseq, conf))


# 生成规则
def gen_rule(L, supportData, minConf=0.7):
    bigRuleList = []
    for i in range(1, len(L)):  # 从二项集开始计算
        for freqSet in L[i]:  # freqSet为所有的k项集
            # 求该三项集的所有非空子集，1项集，2项集，直到k-1项集，用H1表示，为list类型,里面为frozenset类型，
            H1 = list(freqSet)
            all_subset = []
            getSubset(H1, all_subset)  # 生成所有的子集
            calcConf(freqSet, all_subset, supportData, bigRuleList, minConf)
    return bigRuleList

# %% [markdown]
# # 调用算法

# %%
dataset = []
data = list(df['foods'])
for d in data:
    d = d.split('、')
    dataset.append(d)

L, supportData = apriori(dataset, minSupport=0.02) # 最小支持度
rule = gen_rule(L, supportData, minConf=0.35) # 最小置信度

# 输出支持度，置信度大于最小值的规则
rule
# Out:
# frozenset({'细砂糖'}) --> frozenset({'低筋面粉'}) 支持度 0.027746 置信度： 0.377953 lift值为： 5.872978
# frozenset({'低筋面粉'}) --> frozenset({'细砂糖'}) 支持度 0.027746 置信度： 0.431138 lift值为： 5.872978
# frozenset({'酵母'}) --> frozenset({'牛奶'}) 支持度 0.025626 置信度： 0.378917 lift值为： 3.621696
# frozenset({'高筋面粉'}) --> frozenset({'牛奶'}) 支持度 0.020617 置信度： 0.551546 lift值为： 5.271687
# frozenset({'奶粉'}) --> frozenset({'盐'}) 支持度 0.020424 置信度： 0.773723 lift值为： 1.548639
# frozenset({'高筋面粉'}) --> frozenset({'黄油'}) 支持度 0.023699 置信度： 0.634021 lift值为： 7.670319
# frozenset({'细砂糖'}) --> frozenset({'鸡蛋'}) 支持度 0.035067 置信度： 0.47769 lift值为： 1.705098
# frozenset({'低筋面粉'}) --> frozenset({'牛奶'}) 支持度 0.028709 置信度： 0.446108 lift值为： 4.263903
# frozenset({'低筋面粉'}) --> frozenset({'鸡蛋'}) 支持度 0.037958 置信度： 0.58982 lift值为： 2.105342
# frozenset({'细砂糖'}) --> frozenset({'牛奶'}) 支持度 0.037187 置信度： 0.506562 lift值为： 4.841722
# frozenset({'牛奶'}) --> frozenset({'细砂糖'}) 支持度 0.037187 置信度： 0.355433 lift值为： 4.841722
# frozenset({'黄油'}) --> frozenset({'牛奶'}) 支持度 0.04027 置信度： 0.487179 lift值为： 4.656467
# frozenset({'牛奶'}) --> frozenset({'黄油'}) 支持度 0.04027 置信度： 0.384899 lift值为： 4.656467
# frozenset({'玉米油'}) --> frozenset({'鸡蛋'}) 支持度 0.021387 置信度： 0.549505 lift值为： 1.961438
# frozenset({'黄油'}) --> frozenset({'鸡蛋'}) 支持度 0.038343 置信度： 0.463869 lift值为： 1.655765
# frozenset({'黄油'}) --> frozenset({'盐'}) 支持度 0.052408 置信度： 0.634033 lift值为： 1.269043
# frozenset({'牛奶'}) --> frozenset({'鸡蛋'}) 支持度 0.055106 置信度： 0.526703 lift值为： 1.880049
# frozenset({'高筋面粉'}) --> frozenset({'盐'}) 支持度 0.033141 置信度： 0.886598 lift值为： 1.774564
# frozenset({'西红柿'}) --> frozenset({'盐'}) 支持度 0.021773 置信度： 0.672619 lift值为： 1.346276
# frozenset({'酵母'}) --> frozenset({'盐'}) 支持度 0.035453 置信度： 0.524217 lift值为： 1.049242
# frozenset({'面粉'}) --> frozenset({'鸡蛋'}) 支持度 0.031214 置信度： 0.445055 lift值为： 1.588607
# frozenset({'面粉'}) --> frozenset({'盐'}) 支持度 0.038728 置信度： 0.552198 lift值为： 1.105247
# frozenset({'胡椒粉'}) --> frozenset({'盐'}) 支持度 0.030443 置信度： 0.782178 lift值为： 1.565563
# frozenset({'洋葱'}) --> frozenset({'盐'}) 支持度 0.03237 置信度： 0.518519 lift值为： 1.037837
# frozenset({'醋'}) --> frozenset({'生抽'}) 支持度 0.028516 置信度： 0.666667 lift值为： 2.540382
# frozenset({'醋'}) --> frozenset({'盐'}) 支持度 0.030443 置信度： 0.711712 lift值为： 1.424521
# frozenset({'白胡椒粉'}) --> frozenset({'盐'}) 支持度 0.029865 置信度： 0.775 lift值为： 1.551196
# frozenset({'鸡精'}) --> frozenset({'盐'}) 支持度 0.047206 置信度： 0.830508 lift值为： 1.662298
# frozenset({'鸡精'}) --> frozenset({'生抽'}) 支持度 0.02948 置信度： 0.518644 lift值为： 1.976331
# frozenset({'干辣椒'}) --> frozenset({'盐'}) 支持度 0.026397 置信度： 0.61991 lift值为： 1.240775
# frozenset({'小葱'}) --> frozenset({'盐'}) 支持度 0.032948 置信度： 0.589655 lift值为： 1.18022
# frozenset({'淀粉'}) --> frozenset({'料酒'}) 支持度 0.039692 置信度： 0.517588 lift值为： 2.897822
# frozenset({'葱花'}) --> frozenset({'生抽'}) 支持度 0.023892 置信度： 0.420339 lift值为： 1.601732
# frozenset({'花椒'}) --> frozenset({'干辣椒'}) 支持度 0.020424 置信度： 0.381295 lift值为： 8.954393
# frozenset({'干辣椒'}) --> frozenset({'花椒'}) 支持度 0.020424 置信度： 0.479638 lift值为： 8.954393
# frozenset({'洋葱'}) --> frozenset({'生抽'}) 支持度 0.022351 置信度： 0.358025 lift值为： 1.364279
# frozenset({'干辣椒'}) --> frozenset({'生抽'}) 支持度 0.024663 置信度： 0.579186 lift值为： 2.207029
# frozenset({'大蒜'}) --> frozenset({'生抽'}) 支持度 0.024855 置信度： 0.460714 lift值为： 1.755585
# frozenset({'香油'}) --> frozenset({'生抽'}) 支持度 0.026012 置信度： 0.525292 lift值为： 2.001663
# frozenset({'小葱'}) --> frozenset({'生抽'}) 支持度 0.024277 置信度： 0.434483 lift值为： 1.655628
# frozenset({'胡萝卜'}) --> frozenset({'鸡蛋'}) 支持度 0.025434 置信度： 0.352 lift值为： 1.256451
# frozenset({'香菜'}) --> frozenset({'盐'}) 支持度 0.035645 置信度： 0.608553 lift值为： 1.218044
# frozenset({'食用油'}) --> frozenset({'盐'}) 支持度 0.035453 置信度： 0.627986 lift值为： 1.256941
# frozenset({'玉米淀粉'}) --> frozenset({'盐'}) 支持度 0.022158 置信度： 0.542453 lift值为： 1.085742
# frozenset({'香菜'}) --> frozenset({'生抽'}) 支持度 0.028131 置信度： 0.480263 lift值为： 1.830078
# frozenset({'食用油'}) --> frozenset({'生抽'}) 支持度 0.024085 置信度： 0.426621 lift值为： 1.625671
# frozenset({'白糖'}) --> frozenset({'生抽'}) 支持度 0.046628 置信度： 0.454887 lift值为： 1.733381
# frozenset({'八角'}) --> frozenset({'老抽'}) 支持度 0.020809 置信度： 0.55102 lift值为： 5.052643
# frozenset({'大蒜'}) --> frozenset({'盐'}) 支持度 0.028902 置信度： 0.535714 lift值为： 1.072255
# frozenset({'香油'}) --> frozenset({'鸡蛋'}) 支持度 0.020617 置信度： 0.416342 lift值为： 1.486119
# frozenset({'香油'}) --> frozenset({'盐'}) 支持度 0.034682 置信度： 0.700389 lift值为： 1.401859
# frozenset({'鸡蛋'}) --> frozenset({'盐'}) 支持度 0.153757 置信度： 0.548831 lift值为： 1.098508
# frozenset({'酱油'}) --> frozenset({'盐'}) 支持度 0.045472 置信度： 0.706587 lift值为： 1.414264
# frozenset({'葱花'}) --> frozenset({'盐'}) 支持度 0.041618 置信度： 0.732203 lift值为： 1.465536
# frozenset({'油'}) --> frozenset({'盐'}) 支持度 0.050289 置信度： 0.713115 lift值为： 1.42733
# frozenset({'花椒'}) --> frozenset({'姜'}) 支持度 0.026397 置信度： 0.492806 lift值为： 3.291714
# frozenset({'香叶'}) --> frozenset({'八角'}) 支持度 0.020617 置信度： 0.835937 lift值为： 22.135284
# frozenset({'八角'}) --> frozenset({'香叶'}) 支持度 0.020617 置信度： 0.545918 lift值为： 22.135284
# frozenset({'花椒'}) --> frozenset({'料酒'}) 支持度 0.026782 置信度： 0.5 lift值为： 2.799353
# frozenset({'料酒'}) --> frozenset({'姜'}) 支持度 0.076301 置信度： 0.427184 lift值为： 2.853394
# frozenset({'姜'}) --> frozenset({'料酒'}) 支持度 0.076301 置信度： 0.509653 lift值为： 2.853394
# frozenset({'蒜'}) --> frozenset({'姜'}) 支持度 0.06262 置信度： 0.492424 lift值为： 3.289166
# frozenset({'姜'}) --> frozenset({'蒜'}) 支持度 0.06262 置信度： 0.418275 lift值为： 3.289166
# frozenset({'葱'}) --> frozenset({'姜'}) 支持度 0.065896 置信度： 0.551613 lift值为： 3.684519
# frozenset({'姜'}) --> frozenset({'葱'}) 支持度 0.065896 置信度： 0.440154 lift值为： 3.684519
# frozenset({'葱'}) --> frozenset({'料酒'}) 支持度 0.04817 置信度： 0.403226 lift值为： 2.257543
# frozenset({'花椒'}) --> frozenset({'盐'}) 支持度 0.033719 置信度： 0.629496 lift值为： 1.259964
# frozenset({'胡萝卜'}) --> frozenset({'盐'}) 支持度 0.039499 置信度： 0.546667 lift值为： 1.094177
# frozenset({'水'}) --> frozenset({'盐'}) 支持度 0.063006 置信度： 0.565744 lift值为： 1.132361
# frozenset({'姜'}) --> frozenset({'盐'}) 支持度 0.099615 置信度： 0.66538 lift值为： 1.331786
# frozenset({'八角'}) --> frozenset({'盐'}) 支持度 0.022158 置信度： 0.586735 lift值为： 1.174374
# frozenset({'料酒'}) --> frozenset({'盐'}) 支持度 0.121002 置信度： 0.677454 lift值为： 1.355953
# frozenset({'花椒'}) --> frozenset({'生抽'}) 支持度 0.026975 置信度： 0.503597 lift值为： 1.918993
# frozenset({'胡萝卜'}) --> frozenset({'生抽'}) 支持度 0.025819 置信度： 0.357333 lift值为： 1.361645
# frozenset({'姜'}) --> frozenset({'生抽'}) 支持度 0.067437 置信度： 0.45045 lift值为： 1.716474
# frozenset({'八角'}) --> frozenset({'生抽'}) 支持度 0.022929 置信度： 0.607143 lift值为： 2.313562
# frozenset({'老抽'}) --> frozenset({'料酒'}) 支持度 0.047592 置信度： 0.436396 lift值为： 2.443251
# frozenset({'生抽'}) --> frozenset({'料酒'}) 支持度 0.094412 置信度： 0.359765 lift值为： 2.014219
# frozenset({'料酒'}) --> frozenset({'生抽'}) 支持度 0.094412 置信度： 0.528587 lift值为： 2.014219
# frozenset({'葱'}) --> frozenset({'蒜'}) 支持度 0.045087 置信度： 0.377419 lift值为： 2.967889
# frozenset({'蒜'}) --> frozenset({'葱'}) 支持度 0.045087 置信度： 0.354545 lift值为： 2.967889
# frozenset({'老抽'}) --> frozenset({'蚝油'}) 支持度 0.042775 置信度： 0.392226 lift值为： 3.011322
# frozenset({'青椒'}) --> frozenset({'盐'}) 支持度 0.020617 置信度： 0.584699 lift值为： 1.170301
# frozenset({'蚝油'}) --> frozenset({'盐'}) 支持度 0.078805 置信度： 0.60503 lift值为： 1.210992
# frozenset({'蒜'}) --> frozenset({'盐'}) 支持度 0.081888 置信度： 0.643939 lift值为： 1.288872
# frozenset({'葱'}) --> frozenset({'盐'}) 支持度 0.078613 置信度： 0.658065 lift值为： 1.317144
# frozenset({'老抽'}) --> frozenset({'盐'}) 支持度 0.064355 置信度： 0.590106 lift值为： 1.181122
# frozenset({'糖'}) --> frozenset({'盐'}) 支持度 0.108671 置信度： 0.668246 lift值为： 1.337524
# frozenset({'青椒'}) --> frozenset({'生抽'}) 支持度 0.021002 置信度： 0.595628 lift值为： 2.269685
# frozenset({'生抽'}) --> frozenset({'蚝油'}) 支持度 0.093449 置信度： 0.356094 lift值为： 2.733917
# frozenset({'蚝油'}) --> frozenset({'生抽'}) 支持度 0.093449 置信度： 0.717456 lift值为： 2.733917
# frozenset({'蒜'}) --> frozenset({'生抽'}) 支持度 0.069171 置信度： 0.543939 lift值为： 2.072721
# frozenset({'葱'}) --> frozenset({'生抽'}) 支持度 0.057803 置信度： 0.483871 lift值为： 1.843825
# frozenset({'生抽'}) --> frozenset({'老抽'}) 支持度 0.09422 置信度： 0.359031 lift值为： 3.292173
# frozenset({'老抽'}) --> frozenset({'生抽'}) 支持度 0.09422 置信度： 0.863958 lift值为： 3.292173
# frozenset({'糖'}) --> frozenset({'生抽'}) 支持度 0.069364 置信度： 0.42654 lift值为： 1.625363
# frozenset({'生抽'}) --> frozenset({'盐'}) 支持度 0.160501 置信度： 0.611601 lift值为： 1.224145
# frozenset({'淀粉'}) --> frozenset({'盐'}) 支持度 0.051445 置信度： 0.670854 lift值为： 1.342743
# frozenset({'淀粉'}) --> frozenset({'生抽'}) 支持度 0.045472 置信度： 0.592965 lift值为： 2.259536
# frozenset({'土豆'}) --> frozenset({'盐'}) 支持度 0.022736 置信度： 0.548837 lift值为： 1.098521
# frozenset({'细砂糖', '鸡蛋'}) --> frozenset({'牛奶'}) 支持度 0.021773 置信度： 0.620879 lift值为： 5.934369
# frozenset({'细砂糖', '牛奶'}) --> frozenset({'鸡蛋'}) 支持度 0.021773 置信度： 0.585492 lift值为： 2.089893
# frozenset({'鸡蛋', '牛奶'}) --> frozenset({'细砂糖'}) 支持度 0.021773 置信度： 0.395105 lift值为： 5.382138
# frozenset({'盐', '细砂糖'}) --> frozenset({'牛奶'}) 支持度 0.020424 置信度： 0.675159 lift值为： 6.453179
# frozenset({'盐', '牛奶'}) --> frozenset({'细砂糖'}) 支持度 0.020424 置信度： 0.391144 lift值为： 5.328181
# frozenset({'细砂糖', '牛奶'}) --> frozenset({'盐'}) 支持度 0.020424 置信度： 0.549223 lift值为： 1.099293
# frozenset({'盐', '黄油'}) --> frozenset({'高筋面粉'}) 支持度 0.022351 置信度： 0.426471 lift值为： 11.409187
# frozenset({'盐', '高筋面粉'}) --> frozenset({'黄油'}) 支持度 0.022351 置信度： 0.674419 lift值为： 8.15905
# frozenset({'黄油', '高筋面粉'}) --> frozenset({'盐'}) 支持度 0.022351 置信度： 0.943089 lift值为： 1.887634
# frozenset({'高筋面粉'}) --> frozenset({'盐', '黄油'}) 支持度 0.022351 置信度： 0.597938 lift值为： 11.409187
# frozenset({'盐', '黄油'}) --> frozenset({'牛奶'}) 支持度 0.030058 置信度： 0.573529 lift值为： 5.4818
# frozenset({'盐', '牛奶'}) --> frozenset({'黄油'}) 支持度 0.030058 置信度： 0.575646 lift值为： 6.964106
# frozenset({'黄油'}) --> frozenset({'盐', '牛奶'}) 支持度 0.030058 置信度： 0.363636 lift值为： 6.964106
# frozenset({'黄油', '牛奶'}) --> frozenset({'盐'}) 支持度 0.030058 置信度： 0.746411 lift值为： 1.493974
# frozenset({'黄油', '鸡蛋'}) --> frozenset({'牛奶'}) 支持度 0.021002 置信度： 0.547739 lift值为： 5.235292
# frozenset({'黄油', '牛奶'}) --> frozenset({'鸡蛋'}) 支持度 0.021002 置信度： 0.521531 lift值为： 1.861586
# frozenset({'鸡蛋', '牛奶'}) --> frozenset({'黄油'}) 支持度 0.021002 置信度： 0.381119 lift值为： 4.610739
# frozenset({'盐', '黄油'}) --> frozenset({'鸡蛋'}) 支持度 0.024855 置信度： 0.474265 lift值为： 1.692871
# frozenset({'黄油', '鸡蛋'}) --> frozenset({'盐'}) 支持度 0.024855 置信度： 0.648241 lift值为： 1.297482
# frozenset({'盐', '牛奶'}) --> frozenset({'鸡蛋'}) 支持度 0.030636 置信度： 0.586716 lift值为： 2.094261
# frozenset({'鸡蛋', '牛奶'}) --> frozenset({'盐'}) 支持度 0.030636 置信度： 0.555944 lift值为： 1.112746
# frozenset({'盐', '面粉'}) --> frozenset({'鸡蛋'}) 支持度 0.020617 置信度： 0.532338 lift值为： 1.900162
# frozenset({'鸡蛋', '面粉'}) --> frozenset({'盐'}) 支持度 0.020617 置信度： 0.660494 lift值为： 1.322007
# frozenset({'盐', '鸡精'}) --> frozenset({'生抽'}) 支持度 0.023507 置信度： 0.497959 lift值为： 1.89751
# frozenset({'生抽', '鸡精'}) --> frozenset({'盐'}) 支持度 0.023507 置信度： 0.797386 lift值为： 1.596001
# frozenset({'鸡精'}) --> frozenset({'盐', '生抽'}) 支持度 0.023507 置信度： 0.413559 lift值为： 2.576678
# frozenset({'生抽', '淀粉'}) --> frozenset({'料酒'}) 支持度 0.026204 置信度： 0.576271 lift值为： 3.226373
# frozenset({'料酒', '淀粉'}) --> frozenset({'生抽'}) 支持度 0.026204 置信度： 0.660194 lift值为： 2.515718
# frozenset({'盐', '淀粉'}) --> frozenset({'料酒'}) 支持度 0.028131 置信度： 0.546816 lift值为： 3.061464
# frozenset({'料酒', '淀粉'}) --> frozenset({'盐'}) 支持度 0.028131 置信度： 0.708738 lift值为： 1.418569
# frozenset({'淀粉'}) --> frozenset({'盐', '料酒'}) 支持度 0.028131 置信度： 0.366834 lift值为： 3.031639
# frozenset({'生抽', '姜'}) --> frozenset({'老抽'}) 支持度 0.031407 置信度： 0.465714 lift值为： 4.270419
# frozenset({'老抽', '姜'}) --> frozenset({'生抽'}) 支持度 0.031407 置信度： 0.89071 lift值为： 3.394117
# frozenset({'盐', '老抽'}) --> frozenset({'料酒'}) 支持度 0.02736 置信度： 0.42515 lift值为： 2.380288
# frozenset({'料酒', '老抽'}) --> frozenset({'盐'}) 支持度 0.02736 置信度： 0.574899 lift值为： 1.150684
# frozenset({'老抽', '姜'}) --> frozenset({'盐'}) 支持度 0.021965 置信度： 0.622951 lift值为： 1.246863
# frozenset({'老抽', '料酒'}) --> frozenset({'姜'}) 支持度 0.020424 置信度： 0.42915 lift值为： 2.866522
# frozenset({'老抽', '姜'}) --> frozenset({'料酒'}) 支持度 0.020424 置信度： 0.579235 lift值为： 3.242966
# frozenset({'生抽', '鸡蛋'}) --> frozenset({'盐'}) 支持度 0.039884 置信度： 0.683168 lift值为： 1.36739
# frozenset({'料酒', '鸡蛋'}) --> frozenset({'盐'}) 支持度 0.026012 置信度： 0.870968 lift值为： 1.743279
# frozenset({'盐', '白糖'}) --> frozenset({'生抽'}) 支持度 0.025819 置信度： 0.509506 lift值为： 1.941509
# frozenset({'生抽', '白糖'}) --> frozenset({'盐'}) 支持度 0.025819 置信度： 0.553719 lift值为： 1.108292
# frozenset({'糖', '鸡蛋'}) --> frozenset({'盐'}) 支持度 0.030058 置信度： 0.702703 lift值为： 1.406489
# frozenset({'生抽', '糖'}) --> frozenset({'料酒'}) 支持度 0.026204 置信度： 0.377778 lift值为： 2.115067
# frozenset({'糖', '料酒'}) --> frozenset({'生抽'}) 支持度 0.026204 置信度： 0.686869 lift值为： 2.617363
# frozenset({'生抽', '蒜'}) --> frozenset({'料酒'}) 支持度 0.025048 置信度： 0.362117 lift值为： 2.027386
# frozenset({'料酒', '蒜'}) --> frozenset({'生抽'}) 支持度 0.025048 置信度： 0.62201 lift值为： 2.370213
# frozenset({'糖', '姜'}) --> frozenset({'生抽'}) 支持度 0.02158 置信度： 0.691358 lift值为： 2.63447
# frozenset({'生抽', '蒜'}) --> frozenset({'姜'}) 支持度 0.036031 置信度： 0.520891 lift值为： 3.479313
# frozenset({'生抽', '姜'}) --> frozenset({'蒜'}) 支持度 0.036031 置信度： 0.534286 lift值为： 4.201429
# frozenset({'蒜', '姜'}) --> frozenset({'生抽'}) 支持度 0.036031 置信度： 0.575385 lift值为： 2.192545
# frozenset({'蚝油', '姜'}) --> frozenset({'生抽'}) 支持度 0.020617 置信度： 0.708609 lift值为： 2.700207
# frozenset({'生抽', '料酒'}) --> frozenset({'姜'}) 支持度 0.040848 置信度： 0.432653 lift值为： 2.889922
# frozenset({'生抽', '姜'}) --> frozenset({'料酒'}) 支持度 0.040848 置信度： 0.605714 lift值为： 3.391216
# frozenset({'料酒', '姜'}) --> frozenset({'生抽'}) 支持度 0.040848 置信度： 0.535354 lift值为： 2.040004
# frozenset({'盐', '生抽'}) --> frozenset({'料酒'}) 支持度 0.058767 置信度： 0.366146 lift值为： 2.049946
# frozenset({'盐', '料酒'}) --> frozenset({'生抽'}) 支持度 0.058767 置信度： 0.485669 lift值为： 1.850676
# frozenset({'生抽', '料酒'}) --> frozenset({'盐'}) 支持度 0.058767 置信度： 0.622449 lift值为： 1.245858
# frozenset({'糖', '料酒'}) --> frozenset({'盐'}) 支持度 0.030636 置信度： 0.80303 lift值为： 1.607299
# frozenset({'盐', '葱'}) --> frozenset({'料酒'}) 支持度 0.034489 置信度： 0.438725 lift值为： 2.456295
# frozenset({'葱', '料酒'}) --> frozenset({'盐'}) 支持度 0.034489 置信度： 0.716 lift值为： 1.433105
# frozenset({'料酒', '蒜'}) --> frozenset({'盐'}) 支持度 0.028324 置信度： 0.703349 lift值为： 1.407784
# frozenset({'蚝油', '料酒'}) --> frozenset({'盐'}) 支持度 0.026012 置信度： 0.61086 lift值为： 1.222662
# frozenset({'盐', '姜'}) --> frozenset({'生抽'}) 支持度 0.046435 置信度： 0.466151 lift值为： 1.776302
# frozenset({'生抽', '姜'}) --> frozenset({'盐'}) 支持度 0.046435 置信度： 0.688571 lift值为： 1.378205
# frozenset({'糖', '姜'}) --> frozenset({'盐'}) 支持度 0.023892 置信度： 0.765432 lift值为： 1.532045
# frozenset({'盐', '葱'}) --> frozenset({'姜'}) 支持度 0.046243 置信度： 0.588235 lift值为： 3.929139
# frozenset({'盐', '姜'}) --> frozenset({'葱'}) 支持度 0.046243 置信度： 0.464217 lift值为： 3.885942
# frozenset({'葱'}) --> frozenset({'盐', '姜'}) 支持度 0.046243 置信度： 0.387097 lift值为： 3.885942
# frozenset({'葱', '姜'}) --> frozenset({'盐'}) 支持度 0.046243 置信度： 0.701754 lift值为： 1.404591
# frozenset({'盐', '蒜'}) --> frozenset({'姜'}) 支持度 0.039692 置信度： 0.484706 lift值为： 3.237611
# frozenset({'盐', '姜'}) --> frozenset({'蒜'}) 支持度 0.039692 置信度： 0.398453 lift值为： 3.133286
# frozenset({'蒜', '姜'}) --> frozenset({'盐'}) 支持度 0.039692 置信度： 0.633846 lift值为： 1.26867
# frozenset({'盐', '料酒'}) --> frozenset({'姜'}) 支持度 0.054721 置信度： 0.452229 lift值为： 3.020682
# frozenset({'盐', '姜'}) --> frozenset({'料酒'}) 支持度 0.054721 置信度： 0.549323 lift值为： 3.075498
# frozenset({'料酒', '姜'}) --> frozenset({'盐'}) 支持度 0.054721 置信度： 0.717172 lift值为： 1.43545
# frozenset({'姜'}) --> frozenset({'盐', '料酒'}) 支持度 0.054721 置信度： 0.365508 lift值为： 3.020682
# frozenset({'生抽', '葱'}) --> frozenset({'料酒'}) 支持度 0.025048 置信度： 0.433333 lift值为： 2.426106
# frozenset({'葱', '料酒'}) --> frozenset({'生抽'}) 支持度 0.025048 置信度： 0.52 lift值为： 1.981498
# frozenset({'生抽', '葱'}) --> frozenset({'姜'}) 支持度 0.029287 置信度： 0.506667 lift值为： 3.384299
# frozenset({'生抽', '姜'}) --> frozenset({'葱'}) 支持度 0.029287 置信度： 0.434286 lift值为： 3.635392
# frozenset({'葱', '姜'}) --> frozenset({'生抽'}) 支持度 0.029287 置信度： 0.444444 lift值为： 1.693588
# frozenset({'葱', '蒜'}) --> frozenset({'姜'}) 支持度 0.028131 置信度： 0.623932 lift值为： 4.167574
# frozenset({'葱', '姜'}) --> frozenset({'蒜'}) 支持度 0.028131 置信度： 0.426901 lift值为： 3.356991
# frozenset({'蒜', '姜'}) --> frozenset({'葱'}) 支持度 0.028131 置信度： 0.449231 lift值为： 3.760496
# frozenset({'葱', '料酒'}) --> frozenset({'姜'}) 支持度 0.035838 置信度： 0.744 lift值为： 4.969575
# frozenset({'葱', '姜'}) --> frozenset({'料酒'}) 支持度 0.035838 置信度： 0.54386 lift值为： 3.04491
# frozenset({'料酒', '姜'}) --> frozenset({'葱'}) 支持度 0.035838 置信度： 0.469697 lift值为： 3.931818
# frozenset({'蒜', '料酒'}) --> frozenset({'姜'}) 支持度 0.031214 置信度： 0.77512 lift值为： 5.17744
# frozenset({'蒜', '姜'}) --> frozenset({'料酒'}) 支持度 0.031214 置信度： 0.498462 lift值为： 2.790739
# frozenset({'料酒', '姜'}) --> frozenset({'蒜'}) 支持度 0.031214 置信度： 0.409091 lift值为： 3.216942
# frozenset({'生抽', '料酒'}) --> frozenset({'老抽'}) 支持度 0.042197 置信度： 0.446939 lift值为： 4.098255
# frozenset({'生抽', '老抽'}) --> frozenset({'料酒'}) 支持度 0.042197 置信度： 0.447853 lift值为： 2.507396
# frozenset({'料酒', '老抽'}) --> frozenset({'生抽'}) 支持度 0.042197 置信度： 0.88664 lift值为： 3.378605
# frozenset({'老抽'}) --> frozenset({'生抽', '料酒'}) 支持度 0.042197 置信度： 0.386926 lift值为： 4.098255
# frozenset({'生抽', '蚝油'}) --> frozenset({'料酒'}) 支持度 0.032755 置信度： 0.350515 lift值为： 1.962433
# frozenset({'蚝油', '料酒'}) --> frozenset({'生抽'}) 支持度 0.032755 置信度： 0.769231 lift值为： 2.93121
# frozenset({'生抽', '鸡蛋'}) --> frozenset({'蚝油'}) 支持度 0.022158 置信度： 0.379538 lift值为： 2.913908
# frozenset({'蚝油', '鸡蛋'}) --> frozenset({'生抽'}) 支持度 0.022158 置信度： 0.751634 lift值为： 2.864156
# frozenset({'盐', '淀粉'}) --> frozenset({'生抽'}) 支持度 0.028516 置信度： 0.554307 lift值为： 2.112228
# frozenset({'生抽', '淀粉'}) --> frozenset({'盐'}) 支持度 0.028516 置信度： 0.627119 lift值为： 1.255205
# frozenset({'淀粉'}) --> frozenset({'盐', '生抽'}) 支持度 0.028516 置信度： 0.371859 lift值为： 2.316866
# frozenset({'生抽', '糖'}) --> frozenset({'老抽'}) 支持度 0.029865 置信度： 0.430556 lift值为： 3.948027
# frozenset({'糖', '老抽'}) --> frozenset({'生抽'}) 支持度 0.029865 置信度： 0.933735 lift值为： 3.558065
# frozenset({'糖', '蒜'}) --> frozenset({'生抽'}) 支持度 0.023507 置信度： 0.663043 lift值为： 2.526575
# frozenset({'生抽', '蒜'}) --> frozenset({'老抽'}) 支持度 0.026975 置信度： 0.389972 lift值为： 3.575893
# frozenset({'蒜', '老抽'}) --> frozenset({'生抽'}) 支持度 0.026975 置信度： 0.909091 lift值为： 3.464157
# frozenset({'生抽', '淀粉'}) --> frozenset({'蚝油'}) 支持度 0.020424 置信度： 0.449153 lift值为： 3.448375
# frozenset({'蚝油', '淀粉'}) --> frozenset({'生抽'}) 支持度 0.020424 置信度： 0.861789 lift值为： 3.283908
# frozenset({'蚝油', '糖'}) --> frozenset({'生抽'}) 支持度 0.023121 置信度： 0.759494 lift值为： 2.894106
# frozenset({'生抽', '蚝油'}) --> frozenset({'老抽'}) 支持度 0.039306 置信度： 0.420619 lift值为： 3.856909
# frozenset({'生抽', '老抽'}) --> frozenset({'蚝油'}) 支持度 0.039306 置信度： 0.417178 lift值为： 3.20289
# frozenset({'蚝油', '老抽'}) --> frozenset({'生抽'}) 支持度 0.039306 置信度： 0.918919 lift值为： 3.501607
# frozenset({'老抽'}) --> frozenset({'生抽', '蚝油'}) 支持度 0.039306 置信度： 0.360424 lift值为： 3.856909
# frozenset({'生抽', '蒜'}) --> frozenset({'蚝油'}) 支持度 0.026975 置信度： 0.389972 lift值为： 2.994017
# frozenset({'蚝油', '蒜'}) --> frozenset({'生抽'}) 支持度 0.026975 置信度： 0.740741 lift值为： 2.822646
# frozenset({'盐', '糖'}) --> frozenset({'生抽'}) 支持度 0.048362 置信度： 0.445035 lift值为： 1.69584
# frozenset({'生抽', '糖'}) --> frozenset({'盐'}) 支持度 0.048362 置信度： 0.697222 lift值为： 1.39552
# frozenset({'盐', '老抽'}) --> frozenset({'生抽'}) 支持度 0.053757 置信度： 0.835329 lift值为： 3.183083
# frozenset({'生抽', '老抽'}) --> frozenset({'盐'}) 支持度 0.053757 置信度： 0.570552 lift值为： 1.141984
# frozenset({'老抽'}) --> frozenset({'盐', '生抽'}) 支持度 0.053757 置信度： 0.492933 lift值为： 3.071214
# frozenset({'糖', '老抽'}) --> frozenset({'盐'}) 支持度 0.022158 置信度： 0.692771 lift值为： 1.386611
# frozenset({'盐', '葱'}) --> frozenset({'生抽'}) 支持度 0.038728 置信度： 0.492647 lift值为： 1.877267
# frozenset({'葱', '生抽'}) --> frozenset({'盐'}) 支持度 0.038728 置信度： 0.67 lift值为： 1.341034
# frozenset({'盐', '蒜'}) --> frozenset({'生抽'}) 支持度 0.045087 置信度： 0.550588 lift值为： 2.098056
# frozenset({'生抽', '蒜'}) --> frozenset({'盐'}) 支持度 0.045087 置信度： 0.651811 lift值为： 1.304627
# frozenset({'蒜'}) --> frozenset({'盐', '生抽'}) 支持度 0.045087 置信度： 0.354545 lift值为： 2.208993
# frozenset({'糖', '蒜'}) --> frozenset({'盐'}) 支持度 0.026012 置信度： 0.733696 lift值为： 1.468523
# frozenset({'盐', '葱'}) --> frozenset({'蒜'}) 支持度 0.03025 置信度： 0.384804 lift值为： 3.025958
# frozenset({'盐', '蒜'}) --> frozenset({'葱'}) 支持度 0.03025 置信度： 0.369412 lift值为： 3.092334
# frozenset({'葱', '蒜'}) --> frozenset({'盐'}) 支持度 0.03025 置信度： 0.67094 lift值为： 1.342915
# frozenset({'盐', '蚝油'}) --> frozenset({'生抽'}) 支持度 0.05395 置信度： 0.684597 lift值为： 2.608705
# frozenset({'生抽', '蚝油'}) --> frozenset({'盐'}) 支持度 0.05395 置信度： 0.57732 lift值为： 1.15553
# frozenset({'蚝油'}) --> frozenset({'盐', '生抽'}) 支持度 0.05395 置信度： 0.414201 lift值为： 2.580677
# frozenset({'盐', '老抽'}) --> frozenset({'蚝油'}) 支持度 0.023892 置信度： 0.371257 lift值为： 2.850335
# frozenset({'蚝油', '老抽'}) --> frozenset({'盐'}) 支持度 0.023892 置信度： 0.558559 lift值为： 1.117979
# frozenset({'蚝油', '蒜'}) --> frozenset({'盐'}) 支持度 0.022351 置信度： 0.613757 lift值为： 1.22846
# frozenset({'生抽', '葱'}) --> frozenset({'蒜'}) 支持度 0.026204 置信度： 0.453333 lift值为： 3.564848
# frozenset({'生抽', '蒜'}) --> frozenset({'葱'}) 支持度 0.026204 置信度： 0.37883 lift值为： 3.171174
# frozenset({'葱', '蒜'}) --> frozenset({'生抽'}) 支持度 0.026204 置信度： 0.581197 lift值为： 2.214692
# frozenset({'生抽', '葱'}) --> frozenset({'蚝油'}) 支持度 0.020424 置信度： 0.353333 lift值为： 2.712722
# frozenset({'葱', '蚝油'}) --> frozenset({'生抽'}) 支持度 0.020424 置信度： 0.773723 lift值为： 2.948326
# frozenset({'盐', '生抽', '老抽'}) --> frozenset({'姜'}) 支持度 0.020039 置信度： 0.37276 lift值为： 2.489863
# frozenset({'盐', '生抽', '姜'}) --> frozenset({'老抽'}) 支持度 0.020039 置信度： 0.431535 lift值为： 3.957011
# frozenset({'盐', '老抽', '姜'}) --> frozenset({'生抽'}) 支持度 0.020039 置信度： 0.912281 lift值为： 3.476312
# frozenset({'生抽', '老抽', '姜'}) --> frozenset({'盐'}) 支持度 0.020039 置信度： 0.638037 lift值为： 1.277058
# frozenset({'老抽', '姜'}) --> frozenset({'盐', '生抽'}) 支持度 0.020039 置信度： 0.568306 lift值为： 3.540826
# frozenset({'盐', '生抽', '料酒'}) --> frozenset({'老抽'}) 支持度 0.023314 置信度： 0.396721 lift值为： 3.63778
# frozenset({'盐', '生抽', '老抽'}) --> frozenset({'料酒'}) 支持度 0.023314 置信度： 0.433692 lift值为： 2.428112
# frozenset({'盐', '料酒', '老抽'}) --> frozenset({'生抽'}) 支持度 0.023314 置信度： 0.852113 lift值为： 3.247037
# frozenset({'盐', '老抽'}) --> frozenset({'生抽', '料酒'}) 支持度 0.023314 置信度： 0.362275 lift值为： 3.837162
# frozenset({'生抽', '料酒', '老抽'}) --> frozenset({'盐'}) 支持度 0.023314 置信度： 0.552511 lift值为： 1.105875
# frozenset({'料酒', '老抽'}) --> frozenset({'盐', '生抽'}) 支持度 0.023314 置信度： 0.489879 lift值为： 3.052184
# frozenset({'盐', '生抽', '葱'}) --> frozenset({'姜'}) 支持度 0.02158 置信度： 0.557214 lift值为： 3.721931
# frozenset({'盐', '生抽', '姜'}) --> frozenset({'葱'}) 支持度 0.02158 置信度： 0.46473 lift值为： 3.890242
# frozenset({'盐', '葱', '姜'}) --> frozenset({'生抽'}) 支持度 0.02158 置信度： 0.466667 lift值为： 1.778267
# frozenset({'生抽', '葱'}) --> frozenset({'盐', '姜'}) 支持度 0.02158 置信度： 0.373333 lift值为： 3.747776
# frozenset({'生抽', '姜', '葱'}) --> frozenset({'盐'}) 支持度 0.02158 置信度： 0.736842 lift值为： 1.474821
# frozenset({'盐', '生抽', '蒜'}) --> frozenset({'姜'}) 支持度 0.023121 置信度： 0.512821 lift值为： 3.425403
# frozenset({'盐', '生抽', '姜'}) --> frozenset({'蒜'}) 支持度 0.023121 置信度： 0.497925 lift值为： 3.915504
# frozenset({'盐', '蒜', '姜'}) --> frozenset({'生抽'}) 支持度 0.023121 置信度： 0.582524 lift值为： 2.219751
# frozenset({'生抽', '蒜', '姜'}) --> frozenset({'盐'}) 支持度 0.023121 置信度： 0.641711 lift值为： 1.284412
# frozenset({'蒜', '姜'}) --> frozenset({'盐', '生抽'}) 支持度 0.023121 置信度： 0.369231 lift值为： 2.300489
# frozenset({'盐', '料酒', '蒜'}) --> frozenset({'姜'}) 支持度 0.022158 置信度： 0.782313 lift值为： 5.225488
# frozenset({'盐', '蒜', '姜'}) --> frozenset({'料酒'}) 支持度 0.022158 置信度： 0.558252 lift值为： 3.125491
# frozenset({'盐', '料酒', '姜'}) --> frozenset({'蒜'}) 支持度 0.022158 置信度： 0.40493 lift值为： 3.184219
# frozenset({'料酒', '蒜'}) --> frozenset({'盐', '姜'}) 支持度 0.022158 置信度： 0.550239 lift值为： 5.523678
# frozenset({'蒜', '料酒', '姜'}) --> frozenset({'盐'}) 支持度 0.022158 置信度： 0.709877 lift值为： 1.420848
# frozenset({'蒜', '姜'}) --> frozenset({'盐', '料酒'}) 支持度 0.022158 置信度： 0.353846 lift值为： 2.924302
# frozenset({'盐', '葱', '料酒'}) --> frozenset({'姜'}) 支持度 0.026782 置信度： 0.776536 lift值为： 5.186903
# frozenset({'盐', '葱', '姜'}) --> frozenset({'料酒'}) 支持度 0.026782 置信度： 0.579167 lift值为： 3.242584
# frozenset({'盐', '料酒', '姜'}) --> frozenset({'葱'}) 支持度 0.026782 置信度： 0.489437 lift值为： 4.097058
# frozenset({'葱', '料酒'}) --> frozenset({'盐', '姜'}) 支持度 0.026782 置信度： 0.556 lift值为： 5.581509
# frozenset({'葱', '料酒', '姜'}) --> frozenset({'盐'}) 支持度 0.026782 置信度： 0.747312 lift值为： 1.495776
# frozenset({'料酒', '姜'}) --> frozenset({'盐', '葱'}) 支持度 0.026782 置信度： 0.35101 lift值为： 4.465055
# frozenset({'葱', '姜'}) --> frozenset({'盐', '料酒'}) 支持度 0.026782 置信度： 0.406433 lift值为： 3.358895
# frozenset({'盐', '生抽', '糖'}) --> frozenset({'料酒'}) 支持度 0.020617 置信度： 0.426295 lift值为： 2.386699
# frozenset({'盐', '生抽', '料酒'}) --> frozenset({'糖'}) 支持度 0.020617 置信度： 0.35082 lift值为： 2.157292
# frozenset({'盐', '糖', '料酒'}) --> frozenset({'生抽'}) 支持度 0.020617 置信度： 0.672956 lift值为： 2.564348
# frozenset({'生抽', '糖', '料酒'}) --> frozenset({'盐'}) 支持度 0.020617 置信度： 0.786765 lift值为： 1.574743
# frozenset({'糖', '料酒'}) --> frozenset({'盐', '生抽'}) 支持度 0.020617 置信度： 0.540404 lift值为： 3.366983
# frozenset({'盐', '生抽', '料酒'}) --> frozenset({'姜'}) 支持度 0.028902 置信度： 0.491803 lift值为： 3.285018
# frozenset({'盐', '生抽', '姜'}) --> frozenset({'料酒'}) 支持度 0.028902 置信度： 0.622407 lift值为： 3.484671
# frozenset({'盐', '料酒', '姜'}) --> frozenset({'生抽'}) 支持度 0.028902 置信度： 0.528169 lift值为： 2.012626
# frozenset({'生抽', '料酒', '姜'}) --> frozenset({'盐'}) 支持度 0.028902 置信度： 0.707547 lift值为： 1.416186
# frozenset({'生抽', '姜'}) --> frozenset({'盐', '料酒'}) 支持度 0.028902 置信度： 0.428571 lift值为： 3.541856
# frozenset({'料酒', '姜'}) --> frozenset({'盐', '生抽'}) 支持度 0.028902 置信度： 0.378788 lift值为： 2.360035
# frozenset({'盐', '生抽', '蚝油'}) --> frozenset({'老抽'}) 支持度 0.020617 置信度： 0.382143 lift值为： 3.504101
# frozenset({'盐', '生抽', '老抽'}) --> frozenset({'蚝油'}) 支持度 0.020617 置信度： 0.383513 lift值为： 2.944423
# frozenset({'盐', '蚝油', '老抽'}) --> frozenset({'生抽'}) 支持度 0.020617 置信度： 0.862903 lift值为： 3.288155
# frozenset({'生抽', '蚝油', '老抽'}) --> frozenset({'盐'}) 支持度 0.020617 置信度： 0.52451 lift值为： 1.049829
# frozenset({'蚝油', '老抽'}) --> frozenset({'盐', '生抽'}) 支持度 0.020617 置信度： 0.481982 lift值为： 3.002985
# frozenset({'盐', '生抽', '糖'}) --> frozenset({'老抽'}) 支持度 0.020809 置信度： 0.430279 lift值为： 3.94549
# frozenset({'盐', '生抽', '老抽'}) --> frozenset({'糖'}) 支持度 0.020809 置信度： 0.387097 lift值为： 2.38037
# frozenset({'盐', '糖', '老抽'}) --> frozenset({'生抽'}) 支持度 0.020809 置信度： 0.93913 lift值为： 3.578625
# frozenset({'生抽', '糖', '老抽'}) --> frozenset({'盐'}) 支持度 0.020809 置信度： 0.696774 lift值为： 1.394623
# frozenset({'糖', '老抽'}) --> frozenset({'盐', '生抽'}) 支持度 0.020809 置信度： 0.650602 lift值为： 4.053573
# [(frozenset({'细砂糖'}), frozenset({'低筋面粉'}), 0.3779527559055118),
#  (frozenset({'低筋面粉'}), frozenset({'细砂糖'}), 0.4311377245508982),
#  (frozenset({'酵母'}), frozenset({'牛奶'}), 0.3789173789173789),
#  (frozenset({'盐', '面粉'}), frozenset({'鸡蛋'}), 0.5323383084577114),
#  (frozenset({'面粉', '鸡蛋'}), frozenset({'盐'}), 0.6604938271604939),
#  (frozenset({'盐', '鸡精'}), frozenset({'生抽'}), 0.4979591836734694),
#  (frozenset({'生抽', '鸡精'}), frozenset({'盐'}), 0.7973856209150327),
#  (frozenset({'鸡精'}), frozenset({'生抽', '盐'}), 0.41355932203389834),
#  (frozenset({'淀粉', '生抽'}), frozenset({'料酒'}), 0.5762711864406779),
#  (frozenset({'料酒', '淀粉'}), frozenset({'生抽'}), 0.6601941747572815),
#  (frozenset({'淀粉', '盐'}), frozenset({'料酒'}), 0.5468164794007491),
#  (frozenset({'料酒', '淀粉'}), frozenset({'盐'}), 0.7087378640776698),
#  (frozenset({'淀粉'}), frozenset({'料酒', '盐'}), 0.36683417085427134),
#  (frozenset({'姜', '生抽'}), frozenset({'老抽'}), 0.46571428571428575),
#  (frozenset({'姜', '老抽'}), frozenset({'生抽'}), 0.8907103825136612),
#  (frozenset({'盐', '老抽'}), frozenset({'料酒'}), 0.4251497005988024),
#  (frozenset({'料酒', '老抽'}), frozenset({'盐'}), 0.5748987854251012),
#  (frozenset({'姜', '老抽'}), frozenset({'盐'}), 0.6229508196721311),
#  (frozenset({'料酒', '老抽'}), frozenset({'姜'}), 0.4291497975708502),
#  (frozenset({'姜', '老抽'}), frozenset({'料酒'}), 0.5792349726775956),
#  (frozenset({'生抽', '鸡蛋'}), frozenset({'盐'}), 0.6831683168316832),
#  (frozenset({'料酒', '鸡蛋'}), frozenset({'盐'}), 0.8709677419354839),
#  (frozenset({'白糖', '盐'}), frozenset({'生抽'}), 0.5095057034220533),
#  (frozenset({'生抽', '白糖'}), frozenset({'盐'}), 0.5537190082644629),
#  (frozenset({'糖', '鸡蛋'}), frozenset({'盐'}), 0.7027027027027026),
#  (frozenset({'生抽', '糖'}), frozenset({'料酒'}), 0.37777777777777777),
#  (frozenset({'料酒', '糖'}), frozenset({'生抽'}), 0.6868686868686869),
#  (frozenset({'生抽', '蒜'}), frozenset({'料酒'}), 0.362116991643454),
#  (frozenset({'料酒', '蒜'}), frozenset({'生抽'}), 0.6220095693779903),
#  (frozenset({'姜', '糖'}), frozenset({'生抽'}), 0.6913580246913581),
#  (frozenset({'生抽', '蒜'}), frozenset({'姜'}), 0.520891364902507),
#  (frozenset({'姜', '生抽'}), frozenset({'蒜'}), 0.5342857142857143),
#  (frozenset({'姜', '蒜'}), frozenset({'生抽'}), 0.5753846153846154),
#  (frozenset({'姜', '蚝油'}), frozenset({'生抽'}), 0.7086092715231788),
#  (frozenset({'料酒', '生抽'}), frozenset({'姜'}), 0.4326530612244898),
#  (frozenset({'姜', '生抽'}), frozenset({'料酒'}), 0.6057142857142858),
#  (frozenset({'姜', '料酒'}), frozenset({'生抽'}), 0.5353535353535354),
#  (frozenset({'生抽', '盐'}), frozenset({'料酒'}), 0.36614645858343337),
#  (frozenset({'料酒', '盐'}), frozenset({'生抽'}), 0.4856687898089172),
#  (frozenset({'料酒', '生抽'}), frozenset({'盐'}), 0.6224489795918368),
#  (frozenset({'生抽', '蚝油'}), frozenset({'盐'}), 0.5773195876288659),
#  (frozenset({'蚝油'}), frozenset({'生抽', '盐'}), 0.4142011834319526),
#  (frozenset({'盐', '老抽'}), frozenset({'蚝油'}), 0.3712574850299401),
#  (frozenset({'老抽', '蚝油'}), frozenset({'盐'}), 0.5585585585585585),
#  (frozenset({'蒜', '蚝油'}), frozenset({'盐'}), 0.6137566137566137),
#  (frozenset({'生抽', '葱'}), frozenset({'蒜'}), 0.4533333333333333),
#  (frozenset({'生抽', '蒜'}), frozenset({'葱'}), 0.37883008356545955),
#  (frozenset({'葱', '蒜'}), frozenset({'生抽'}), 0.5811965811965811),
#  (frozenset({'生抽', '葱'}), frozenset({'蚝油'}), 0.3533333333333334),
#  (frozenset({'葱', '蚝油'}), frozenset({'生抽'}), 0.7737226277372263),
#  (frozenset({'生抽', '盐', '老抽'}), frozenset({'姜'}), 0.37275985663082434),
#  (frozenset({'姜', '生抽', '盐'}), frozenset({'老抽'}), 0.43153526970954353),
#  (frozenset({'姜', '盐', '老抽'}), frozenset({'生抽'}), 0.9122807017543859),
#  (frozenset({'姜', '生抽', '老抽'}), frozenset({'盐'}), 0.6380368098159508),
#  (frozenset({'姜', '老抽'}), frozenset({'生抽', '盐'}), 0.5683060109289617),
#  (frozenset({'料酒', '生抽', '盐'}), frozenset({'老抽'}), 0.39672131147540984),
#  (frozenset({'生抽', '盐', '老抽'}), frozenset({'料酒'}), 0.4336917562724014),
#  (frozenset({'料酒', '盐', '老抽'}), frozenset({'生抽'}), 0.852112676056338),
#  (frozenset({'盐', '老抽'}), frozenset({'料酒', '生抽'}), 0.36227544910179643),
#  (frozenset({'料酒', '生抽', '老抽'}), frozenset({'盐'}), 0.5525114155251142),
#  (frozenset({'料酒', '老抽'}), frozenset({'生抽', '盐'}), 0.4898785425101214),
#  (frozenset({'生抽', '盐', '葱'}), frozenset({'姜'}), 0.5572139303482587),
#  (frozenset({'姜', '生抽', '盐'}), frozenset({'葱'}), 0.46473029045643155),
#  (frozenset({'姜', '盐', '葱'}), frozenset({'生抽'}), 0.46666666666666673),
#  (frozenset({'生抽', '葱'}), frozenset({'姜', '盐'}), 0.37333333333333335),
#  (frozenset({'姜', '生抽', '葱'}), frozenset({'盐'}), 0.7368421052631579),
#  (frozenset({'生抽', '盐', '蒜'}), frozenset({'姜'}), 0.5128205128205128),
#  (frozenset({'姜', '生抽', '盐'}), frozenset({'蒜'}), 0.49792531120331945),
#  (frozenset({'姜', '盐', '蒜'}), frozenset({'生抽'}), 0.5825242718446602),
#  (frozenset({'姜', '生抽', '蒜'}), frozenset({'盐'}), 0.6417112299465241),
#  (frozenset({'姜', '蒜'}), frozenset({'生抽', '盐'}), 0.3692307692307692),
#  (frozenset({'料酒', '盐', '蒜'}), frozenset({'姜'}), 0.782312925170068),
#  (frozenset({'姜', '盐', '蒜'}), frozenset({'料酒'}), 0.558252427184466),
#  (frozenset({'姜', '料酒', '盐'}), frozenset({'蒜'}), 0.40492957746478875),
#  (frozenset({'料酒', '蒜'}), frozenset({'姜', '盐'}), 0.5502392344497608),
#  (frozenset({'姜', '料酒', '蒜'}), frozenset({'盐'}), 0.7098765432098766),
#  (frozenset({'姜', '蒜'}), frozenset({'料酒', '盐'}), 0.35384615384615387),
#  (frozenset({'料酒', '盐', '葱'}), frozenset({'姜'}), 0.7765363128491621),
#  (frozenset({'姜', '盐', '葱'}), frozenset({'料酒'}), 0.5791666666666667),
#  (frozenset({'姜', '料酒', '盐'}), frozenset({'葱'}), 0.4894366197183099),
#  (frozenset({'料酒', '葱'}), frozenset({'姜', '盐'}), 0.556),
#  (frozenset({'姜', '料酒', '葱'}), frozenset({'盐'}), 0.7473118279569892),
#  (frozenset({'姜', '料酒'}), frozenset({'盐', '葱'}), 0.351010101010101),
#  (frozenset({'姜', '葱'}), frozenset({'料酒', '盐'}), 0.40643274853801176),
#  (frozenset({'生抽', '盐', '糖'}), frozenset({'料酒'}), 0.4262948207171315),
#  (frozenset({'料酒', '生抽', '盐'}), frozenset({'糖'}), 0.3508196721311475),
#  (frozenset({'料酒', '盐', '糖'}), frozenset({'生抽'}), 0.6729559748427673),
#  (frozenset({'料酒', '生抽', '糖'}), frozenset({'盐'}), 0.7867647058823529),
#  (frozenset({'料酒', '糖'}), frozenset({'生抽', '盐'}), 0.5404040404040403),
#  (frozenset({'料酒', '生抽', '盐'}), frozenset({'姜'}), 0.4918032786885246),
#  (frozenset({'姜', '生抽', '盐'}), frozenset({'料酒'}), 0.6224066390041494),
#  (frozenset({'姜', '料酒', '盐'}), frozenset({'生抽'}), 0.528169014084507),
#  (frozenset({'姜', '料酒', '生抽'}), frozenset({'盐'}), 0.7075471698113207),
#  (frozenset({'姜', '生抽'}), frozenset({'料酒', '盐'}), 0.42857142857142855),
#  (frozenset({'姜', '料酒'}), frozenset({'生抽', '盐'}), 0.3787878787878788),
#  (frozenset({'生抽', '盐', '蚝油'}), frozenset({'老抽'}), 0.3821428571428571),
#  (frozenset({'生抽', '盐', '老抽'}), frozenset({'蚝油'}), 0.38351254480286734),
#  (frozenset({'盐', '老抽', '蚝油'}), frozenset({'生抽'}), 0.8629032258064516),
#  (frozenset({'生抽', '老抽', '蚝油'}), frozenset({'盐'}), 0.5245098039215685),
#  (frozenset({'老抽', '蚝油'}), frozenset({'生抽', '盐'}), 0.48198198198198194),
#  (frozenset({'生抽', '盐', '糖'}), frozenset({'老抽'}), 0.4302788844621514),
#  (frozenset({'生抽', '盐', '老抽'}), frozenset({'糖'}), 0.3870967741935484),
#  (frozenset({'盐', '糖', '老抽'}), frozenset({'生抽'}), 0.9391304347826087),
#  (frozenset({'生抽', '糖', '老抽'}), frozenset({'盐'}), 0.6967741935483871),
#  (frozenset({'糖', '老抽'}), frozenset({'生抽', '盐'}), 0.6506024096385542)]

# %% [markdown]
# # 结果说明

# %% [markdown]
# 随机抽取一条结果解读
#
# frozenset({'细砂糖', '鸡蛋'}) --> frozenset({'牛奶'}) 支持度 0.021773 置信度： 0.620879
#
# 表示食材中同时有细砂糖/鸡蛋，牛奶的概率为62%，而这种按情况发生的概率为2.1%
